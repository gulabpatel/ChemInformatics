# %% [markdown]
# ## **1. Import libraries**

# %%
! pip install lazypredict
# Out:
# Collecting lazypredict
#   Downloading https://files.pythonhosted.org/packages/5f/db/1566dca1050ea74e9474dca0f1e7bbffcb0c3e694cf92e7e6e7ef9fca3af/lazypredict-0.2.7-py2.py3-none-any.whl
# Requirement already satisfied: Click>=7.0 in /usr/local/lib/python3.6/dist-packages (from lazypredict) (7.1.2)
# Installing collected packages: lazypredict
# Successfully installed lazypredict-0.2.7

# %%
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
import lazypredict
from lazypredict.Supervised import LazyRegressor
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.utils.testing module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.utils. Anything that cannot be imported from sklearn.utils is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %% [markdown]
# ## **2. Load the data set**

# %%
! wget https://github.com/dataprofessor/data/raw/master/acetylcholinesterase_06_bioactivity_data_3class_pIC50_pubchem_fp.csv
# Out:
# --2021-01-22 16:02:42--  https://github.com/dataprofessor/data/raw/master/acetylcholinesterase_06_bioactivity_data_3class_pIC50_pubchem_fp.csv
# Resolving github.com (github.com)... 140.82.113.3
# Connecting to github.com (github.com)|140.82.113.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/dataprofessor/data/master/acetylcholinesterase_06_bioactivity_data_3class_pIC50_pubchem_fp.csv [following]
# --2021-01-22 16:02:43--  https://raw.githubusercontent.com/dataprofessor/data/master/acetylcholinesterase_06_bioactivity_data_3class_pIC50_pubchem_fp.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8363909 (8.0M) [text/plain]
# Saving to: ‘acetylcholinesterase_06_bioactivity_data_3class_pIC50_pubchem_fp.csv’
#
# acetylcholinesteras 100%[===================>]   7.98M  50.9MB/s    in 0.2s
#
# 2021-01-22 16:02:43 (50.9 MB/s) - ‘acetylcholinesterase_06_bioactivity_data_3class_pIC50_pubchem_fp.csv’ saved [8363909/8363909]

# %%
df = pd.read_csv('acetylcholinesterase_06_bioactivity_data_3class_pIC50_pubchem_fp.csv')

# %%
X = df.drop('pIC50', axis=1)
Y = df.pIC50

# %% [markdown]
# ## **3. Data pre-processing**

# %%
# Examine X dimension
X.shape
# Out:
# (4695, 881)

# %%
# Remove low variance features
from sklearn.feature_selection import VarianceThreshold
selection = VarianceThreshold(threshold=(.8 * (1 - .8)))    
X = selection.fit_transform(X)
X.shape
# Out:
# (4695, 137)

# %%
# Perform data splitting using 80/20 ratio
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %% [markdown]
# ## **4. Compare ML algorithms**

# %%
# Defines and builds the lazyclassifier
clf = LazyRegressor(verbose=0,ignore_warnings=True, custom_metric=None)
models_train, predictions_train = clf.fit(X_train, X_train, Y_train, Y_train)
models_test, predictions_test = clf.fit(X_train, X_test, Y_train, Y_test)
# Out:
#  90%|████████▉ | 35/39 [00:58<00:11,  2.88s/it]
# [16:04:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 100%|██████████| 39/39 [01:00<00:00,  1.54s/it]
#  90%|████████▉ | 35/39 [00:50<00:08,  2.17s/it]
# [16:04:56] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 100%|██████████| 39/39 [00:52<00:00,  1.34s/it]

# %%
# Performance table of the training set (80% subset)
predictions_train
# Out:
#                                                  R-Squared  ...  Time Taken
# Model                                                       ...
# DecisionTreeRegressor                                 0.86  ...        0.15
# ExtraTreeRegressor                                    0.86  ...        0.13
# ExtraTreesRegressor                                   0.86  ...        6.00
# GaussianProcessRegressor                              0.86  ...        5.15
# RandomForestRegressor                                 0.83  ...        4.75
# BaggingRegressor                                      0.81  ...        0.61
# MLPRegressor                                          0.77  ...        7.20
# HistGradientBoostingRegressor                         0.69  ...        2.49
# LGBMRegressor                                         0.69  ...        0.53
# KNeighborsRegressor                                   0.65  ...        3.05
# SVR                                                   0.58  ...        6.60
# NuSVR                                                 0.57  ...        4.88
# GradientBoostingRegressor                             0.46  ...        1.78
# XGBRegressor                                          0.46  ...        1.30
# Ridge                                                 0.33  ...        0.09
# LassoCV                                               0.33  ...        4.04
# ElasticNetCV                                          0.33  ...        3.79
# RidgeCV                                               0.33  ...        0.21
# TransformedTargetRegressor                            0.33  ...        0.08
# LinearRegression                                      0.33  ...        0.13
# SGDRegressor                                          0.32  ...        0.16
# BayesianRidge                                         0.32  ...        0.20
# HuberRegressor                                        0.31  ...        0.82
# LassoLarsCV                                           0.31  ...        0.47
# LassoLarsIC                                           0.31  ...        0.11
# LinearSVR                                             0.30  ...        0.81
# AdaBoostRegressor                                     0.23  ...        0.84
# Lars                                                  0.23  ...        0.12
# OrthogonalMatchingPursuitCV                           0.23  ...        0.15
# OrthogonalMatchingPursuit                             0.23  ...        0.06
# LarsCV                                                0.15  ...        0.50
# Lasso                                                 0.00  ...        0.09
# ElasticNet                                            0.00  ...        0.06
# DummyRegressor                                        0.00  ...        0.04
# LassoLars                                             0.00  ...        0.11
# PassiveAggressiveRegressor                           -0.13  ...        0.12
# KernelRidge                                         -13.70  ...        1.50
# RANSACRegressor               -177394519750505689776128.00  ...        1.01
#
# [38 rows x 3 columns]

# %%
# Performance table of the test set (20% subset)
predictions_test
# Out:
#                                                  R-Squared  ...  Time Taken
# Model                                                       ...
# HistGradientBoostingRegressor                         0.54  ...        2.17
# LGBMRegressor                                         0.54  ...        0.48
# RandomForestRegressor                                 0.52  ...        4.59
# BaggingRegressor                                      0.48  ...        0.55
# NuSVR                                                 0.48  ...        3.52
# SVR                                                   0.48  ...        4.37
# KNeighborsRegressor                                   0.46  ...        0.95
# MLPRegressor                                          0.45  ...        7.11
# GradientBoostingRegressor                             0.42  ...        1.74
# XGBRegressor                                          0.42  ...        1.20
# ExtraTreesRegressor                                   0.34  ...        5.99
# Ridge                                                 0.32  ...        0.05
# RidgeCV                                               0.32  ...        0.17
# ElasticNetCV                                          0.32  ...        3.82
# LassoCV                                               0.32  ...        4.01
# ExtraTreeRegressor                                    0.31  ...        0.13
# SGDRegressor                                          0.31  ...        0.15
# TransformedTargetRegressor                            0.31  ...        0.07
# LinearRegression                                      0.31  ...        0.09
# BayesianRidge                                         0.31  ...        0.16
# LassoLarsCV                                           0.31  ...        0.45
# LassoLarsIC                                           0.31  ...        0.10
# HuberRegressor                                        0.31  ...        0.85
# LinearSVR                                             0.29  ...        0.88
# DecisionTreeRegressor                                 0.28  ...        0.17
# OrthogonalMatchingPursuit                             0.24  ...        0.04
# OrthogonalMatchingPursuitCV                           0.24  ...        0.15
# Lars                                                  0.21  ...        0.12
# AdaBoostRegressor                                     0.21  ...        0.80
# LarsCV                                                0.15  ...        0.48
# Lasso                                                -0.00  ...        0.06
# ElasticNet                                           -0.00  ...        0.04
# DummyRegressor                                       -0.00  ...        0.03
# LassoLars                                            -0.00  ...        0.05
# PassiveAggressiveRegressor                           -0.22  ...        0.11
# GaussianProcessRegressor                             -4.99  ...        4.16
# KernelRidge                                         -13.82  ...        1.31
# RANSACRegressor               -225543784142202044678144.00  ...        1.21
#
# [38 rows x 3 columns]

# %% [markdown]
# ## **5. Data visualization of model performance**

# %%
# Bar plot of R-squared values
import matplotlib.pyplot as plt
import seaborn as sns

#train["R-Squared"] = [0 if i < 0 else i for i in train.iloc[:,0] ]

plt.figure(figsize=(5, 10))
sns.set_theme(style="whitegrid")
ax = sns.barplot(y=predictions_train.index, x="R-Squared", data=predictions_train)
ax.set(xlim=(0, 1))
# Out:
# [(0.0, 1.0)]

# %%
# Bar plot of RMSE values
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(5, 10))
sns.set_theme(style="whitegrid")
ax = sns.barplot(y=predictions_train.index, x="RMSE", data=predictions_train)
ax.set(xlim=(0, 10))
# Out:
# [(0.0, 10.0)]

# %%
# Bar plot of calculation time
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(5, 10))
sns.set_theme(style="whitegrid")
ax = sns.barplot(y=predictions_train.index, x="Time Taken", data=predictions_train)
ax.set(xlim=(0, 10))
# Out:
# [(0.0, 10.0)]

# %% [markdown]
# ----------------------------
